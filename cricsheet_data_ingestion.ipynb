# %% [markdown]
# # Cricsheet Data Exploration and Ingestion
# This notebook is meant to provide an overview of Cricsheet data and add it to tables of a SQLite database.

# %%
# %load_ext sql
# %sql sqlite:////Users/tejaskale/Code/cricsheet_data/data/cricsheet.sqlite

# %%
import json
import os

# %% [markdown]
# ### Data exploration

# %%
data_dir: str = "./data"
json_files_dir: str = "raw_data"

# %% [markdown]
# The raw data downloaded from [Cricsheet](https://cricsheet.org/downloads/#experimental) consists of one JSON file per cricket match. There are 15,933 files available with the data available on January 8, 2024.

# %%
num_json_files: int = len(os.listdir(os.path.join(data_dir, json_files_dir)))
num_json_files
# Out:
# 15933

# %%
json_file_names: list = os.listdir(os.path.join(data_dir, json_files_dir))

# %%
sample_json_file_name: str = json_file_names[0]

# %% [markdown]
# Every JSON file contains three keys:
# - `meta`: metadata containing data version, when the file was created, and revision number.
# - `info`: information about the match
# - `innings`: a list with one dictionary per innings i.e. a list of 2 for one-day and T20I games and 4 for test matches.
#     + Each innings data is a dictionary with the key `team` denoting the batting team and the key `overs` providing ball-by-ball data.

# %%
with open(os.path.join(data_dir, json_files_dir, sample_json_file_name), "r") as f:
    sample_json = json.load(f)
sample_json.keys()
# Out:
# dict_keys(['meta', 'info', 'innings'])

# %%
sample_json["meta"]
# Out:
# {'data_version': '1.0.0', 'created': '2020-11-16', 'revision': 2}

# %%
sample_json["info"].keys()
# Out:
# dict_keys(['balls_per_over', 'city', 'dates', 'event', 'gender', 'match_type', 'missing', 'officials', 'outcome', 'players', 'registry', 'season', 'team_type', 'teams', 'toss', 'venue'])

# %%
sample_json["info"]
# Out:
# {'balls_per_over': 6,
#  'city': 'Nairobi',
#  'dates': ['2010-02-20', '2010-02-21', '2010-02-22', '2010-02-23'],
#  'event': {'name': 'ICC Intercontinental Shield'},
#  'gender': 'male',
#  'match_type': 'MDM',
#  'missing': ['player_of_match'],
#  'officials': {'match_referees': ['D Govindjee'],
#   'reserve_umpires': ['D Angara'],
#   'umpires': ['Zameer Haider', 'SR Modi']},
#  'outcome': {'winner': 'Kenya', 'by': {'wickets': 5}},
#  'players': {'Netherlands': ['AN Kervezee',
#    'ES Szwarczynski',
#    'B Zuiderent',
#    'NA Statham',
#    'RN ten Doeschate',
#    'Mudassar Bukhari',
#    'PW Borren',
#    'AF Buurman',
#    'MBS Jonkman',
#    'RG Nijman',
#    'PM Seelaar'],
#   'Kenya': ['DO Obuya',
#    'RR Patel',
#    'CO Obuya',
#    'AA Obanda',
#    'MA Ouma',
#    'JK Kamande',
#    'NN Odhiambo',
#    'HA Varaiya',
#    'E Otieno',
#    'NM Odhiambo',
#    'JO Ngoche']},
#  'registry': {'people': {'AA Obanda': '7081491e',
#    'AF Buurman': '03d3dd8e',
#    'AN Kervezee': 'dc36a6a5',
#    'B Zuiderent': 'd953ed6a',
#    'CO Obuya': '5680f1ad',
#    'D Angara': 'bfa866cc',
#    'D Govindjee': '8b4c4069',
#    'DO Obuya': '6ed3d5ac',
#    'E Otieno': 'c57fa67e',
#    'ES Szwarczynski': '6a7239a7',
#    'HA Varaiya': 'eeeebf82',
#    'JK Kamande': '270b3f8e',
#    'JO Ngoche': 'a9a4df9f',
#    'MA Ouma': '0939c670',
#    'MBS Jonkman': '74ef405a',
#    'Mudassar Bukhari': '37312a74',
#    'NA Statham': '0db94786',
#    'NM Odhiambo': 'c07a1f41',
#    'NN Odhiambo': '753b5a2d',
#    'PM Seelaar': 'abbdca1a',
#    'PW Borren': '91052c96',
#    'RG Nijman': '235a247a',
#    'RN ten Doeschate': '4ec07775',
#    'RR Patel': '7fa6bd8e',
#    'SR Modi': '4a9a7712',
#    'Zameer Haider': '5537565f'}},
#  'season': '2009/10',
#  'team_type': 'international',
#  'teams': ['Netherlands', 'Kenya'],
#  'toss': {'decision': 'bat', 'winner': 'Netherlands'},
#  'venue': 'Gymkhana Club Ground'}

# %%
len(sample_json["innings"])
# Out:
# 4

# %%
sample_json["innings"][0]
# Out:
# {'team': 'Netherlands',
#  'overs': [{'over': 0,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'ES Szwarczynski',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'ES Szwarczynski',
#      'bowler': 'NN Odhiambo',
#      'extras': {'legbyes': 1},
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'ES Szwarczynski',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'ES Szwarczynski',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'ES Szwarczynski',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'ES Szwarczynski',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 1,
#    'deliveries': [{'batter': 'ES Szwarczynski',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'ES Szwarczynski',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0},
#      'wickets': [{'player_out': 'ES Szwarczynski',
#        'fielders': [{'name': 'CO Obuya'}],
#        'kind': 'caught'}]},
#     {'batter': 'B Zuiderent',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'B Zuiderent',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'B Zuiderent',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'B Zuiderent',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 2,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'extras': {'wides': 1},
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#   {'over': 3,
#    'deliveries': [{'batter': 'B Zuiderent',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'B Zuiderent',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'B Zuiderent',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'B Zuiderent',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 4,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'B Zuiderent',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'B Zuiderent',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0},
#      'wickets': [{'player_out': 'B Zuiderent',
#        'fielders': [{'name': 'MA Ouma'}],
#        'kind': 'caught'}]}]},
#   {'over': 5,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 6,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 7,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 8,
#    'deliveries': [{'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 9,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 10,
#    'deliveries': [{'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 11,
#    'deliveries': [{'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'extras': {'legbyes': 4},
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 4, 'total': 4}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 12,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'AN Kervezee',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 13,
#    'deliveries': [{'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 14,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'NA Statham',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'NA Statham',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 15,
#    'deliveries': [{'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'extras': {'noballs': 1},
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'AN Kervezee',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 16,
#    'deliveries': [{'batter': 'AN Kervezee',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0},
#      'wickets': [{'player_out': 'AN Kervezee',
#        'fielders': [{'name': 'HA Varaiya'}],
#        'kind': 'caught'}]},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#   {'over': 17,
#    'deliveries': [{'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 18,
#    'deliveries': [{'batter': 'NA Statham',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'extras': {'noballs': 1},
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 19,
#    'deliveries': [{'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 20,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'NA Statham',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 21,
#    'deliveries': [{'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'NA Statham',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0},
#      'wickets': [{'player_out': 'NA Statham',
#        'fielders': [{'name': 'MA Ouma'}],
#        'kind': 'caught'}]},
#     {'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 22,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 23,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 24,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 25,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 26,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 27,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#   {'over': 28,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 29,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 30,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 31,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 32,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 33,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 34,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 35,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 36,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#   {'over': 37,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 38,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 39,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 40,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JK Kamande',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JK Kamande',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JK Kamande',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JK Kamande',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JK Kamande',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JK Kamande',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 41,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 42,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 43,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 44,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 45,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 46,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'extras': {'noballs': 1},
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 4, 'extras': 1, 'total': 5}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 47,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 48,
#    'deliveries': [{'batter': 'PW Borren',
#      'bowler': 'JK Kamande',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'PW Borren',
#      'bowler': 'JK Kamande',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JK Kamande',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JK Kamande',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JK Kamande',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JK Kamande',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 49,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PW Borren',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 50,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JK Kamande',
#      'non_striker': 'PW Borren',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PW Borren',
#      'bowler': 'JK Kamande',
# ...
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 89,
#    'deliveries': [{'batter': 'MBS Jonkman',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'extras': {'legbyes': 2},
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 0, 'extras': 2, 'total': 2}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 90,
#    'deliveries': [{'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'extras': {'byes': 4},
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 4, 'total': 4}}]},
#   {'over': 91,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'JO Ngoche',
#      'extras': {'noballs': 1},
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'JO Ngoche',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 92,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 93,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'MBS Jonkman',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'MBS Jonkman',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0},
#      'wickets': [{'player_out': 'MBS Jonkman',
#        'fielders': [{'name': 'MA Ouma'}],
#        'kind': 'caught'}]},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'extras': {'wides': 1},
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 94,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NM Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 95,
#    'deliveries': [{'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 96,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 97,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 98,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#   {'over': 99,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 100,
#    'deliveries': [{'batter': 'PM Seelaar',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 101,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 102,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'HA Varaiya',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 103,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'E Otieno',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#     {'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 104,
#    'deliveries': [{'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#     {'batter': 'RN ten Doeschate',
#      'bowler': 'NN Odhiambo',
#      'non_striker': 'PM Seelaar',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#   {'over': 105,
#    'deliveries': [{'batter': 'PM Seelaar',
#      'bowler': 'E Otieno',
#      'non_striker': 'RN ten Doeschate',
#      'runs': {'batter': 0, 'extras': 0, 'total': 0},
#      'wickets': [{'player_out': 'PM Seelaar',
#        'fielders': [{'name': 'JK Kamande'}],
#        'kind': 'caught'}]}]}]}

# %% [markdown]
# ## Data modelling
#
# In order to quickly and efficiently retrieve and use the data, it is necessary to store it in a database in order to leverage SQL and other modern database tools that ease analysis. Hence, let us build a pipeline that inserts this data into a OLTP-style database. The tables in this database are designed to avoid redundancy and make it easy to join tables in order to get specific bits of data. First, let us create the tables.

# %%
# %%sql
#
# create table if not exists team
# (
#     team_id int primary key,
#     name    varchar(20) not null
# );
#
# create table if not exists player
# (
#     player_id int primary key,
#     name      varchar(100) not null,
#     gender    varchar(1)   not null,
#     team_id   int          not null,
#     foreign key (team_id) references team (team_id)
# );
#
# create table if not exists venue
# (
#     venue_id int primary key,
#     name     varchar(100) not null,
#     city     varchar(20)  not null
# );
#
# create table if not exists event
# (
#     event_id int primary key,
#     name     varchar(100) not null
# );
#
# create table if not exists umpire
# (
#     umpire_id int primary key,
#     name      varchar(100) not null
# );
#
# create table if not exists match_type
# (
#     type_id int primary key,
#     name    varchar(10) not null
# );
#
# create table if not exists match
# (
#     match_id int primary key,
#     type     varchar(10) not null,
#     venue    int         not null,
#     event    int         not null,
#     toss     int         not null,
#     foreign key (type) references match_type (type_id),
#     foreign key (venue) references venue(venue_id),
#     foreign key (event) references event (event_id),
#     foreign key (toss) references team (team_id)
# );
#
# create table if not exists dates
# (
#     match_id   int  not null,
#     match_date date not null,
#     foreign key (match_id) references match (match_id)
# );
#
# create table if not exists officiates
# (
#     match_id  int not null,
#     umpire_id int not null,
#     foreign key (match_id) references match (match_id),
#     foreign key (umpire_id) references umpire (umpire_id)
# );
#
# create table if not exists team_plays
# (
#     match_id int not null,
#     team_id  int not null,
#     foreign key (match_id) references match (match_id),
#     foreign key (team_id) references team (team_id)
# );
#
# create table if not exists player_plays
# (
#     match_id  int not null,
#     player_id int not null,
#     foreign key (match_id) references match (match_id),
#     foreign key (player_id) references player (player_id)
# );
#
# create table if not exists extras
# (
#     extras_id    int primary key,
#     name         varchar(20) not null,
#     has_free_hit bool        not null
# );
#
# create table if not exists ball
# (
#     match_id        int not null,
#     innings         int not null,
#     over            int not null,
#     ball            int not null,
#     batting_team    int not null,
#     bowling_team    int not null,
#     striker         int not null,
#     non_striker     int not null,
#     bowler          int not null,
#     non_extras_runs int not null,
#     extras_runs     int not null,
#     extras          int,
#     total_runs      int not null,
#     foreign key (match_id) references match (match_id),
#     foreign key (batting_team) references team (team_id),
#     foreign key (bowling_team) references team (team_id),
#     foreign key (striker) references player (player_id),
#     foreign key (non_striker) references player (player_id),
#     foreign key (bowler) references player (player_id),
#     foreign key (extras) references extras (extras_id)
# );

# %%
match_id: int = int(sample_json_file_name.split(".")[0])
match_id
# Out:
# 438938

# %%
def get_match_id(json_file_name: str) -> int:
    """
    Get match ID from JSON file name.
    
    :param json_file_name: Name of the JSON file. 
    :return: Match ID as integer.
    """
    return int(json_file_name.split(".")[0])

# %%
def load_match_json(json_file_path: str) -> dict:
    """
    Load a JSON file and return it as a dictionary.

    :param json_file_path: Path to the JSON file.
    :return: The loaded JSON as a dictionary.
    """
    with open(json_file_path, "r") as json_file:
        match_data = json.load(json_file)
    return match_data
